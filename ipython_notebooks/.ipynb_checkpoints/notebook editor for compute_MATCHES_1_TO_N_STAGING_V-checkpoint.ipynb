# %%
# -*- coding: utf-8 -*-
import dataiku
import pandas as pd, numpy as np
from dataiku import pandasutils as pdu

# Read recipe inputs
CALCULATED_DRAW_DOWNS = dataiku.Dataset("CALCULATED_DRAW_DOWNS")
CALCULATED_DRAW_DOWNS_df = CALCULATED_DRAW_DOWNS.get_dataframe()

CALCULATED_DRAW_UPS = dataiku.Dataset("CALCULATED_DRAW_UPS")
CALCULATED_DRAW_UPS_df = CALCULATED_DRAW_UPS.get_dataframe()

COMMON_WORDS = dataiku.Dataset("NAFCUSTOMER_COMMON_WORDS_IN_NAMES")
COMMON_WORDS_df = COMMON_WORDS.get_dataframe()

# %%
df_down_full = CALCULATED_DRAW_DOWNS_df
df_up_full = CALCULATED_DRAW_UPS_df
df_common = COMMON_WORDS_df

df_down_full.sort_values(['CUSTOMER'], inplace=True)
df_up_full.sort_values(['CUSTOMER'], inplace=True)
df_common.sort_values(['WORD'], inplace=True)

print(len(df_down_full), "draw downs full")
print(len(df_up_full), "draw ups full")
print(len(df_common), "common words")
# Out:
# 14444 draw downs full
# 5848 draw ups full
# 2173 common words

# %%
import string

_common_words = df_common.WORD.unique()
print(len(_common_words), "screening against common words")

class Draw_Down_Customer:

    def __init__(self, name, draw_down_date, active_card_max):

        self.CUSTOMER = name
        self.DRAW_DOWN_DATE = draw_down_date
        self.ACTIVE_CARD_MAX = active_card_max

        self.MATCHING_CUSTOMERS = []
        self.PERCENT_DIFFERENCE = []
        self.DAYS_DIFFERENCE = []
        self.DRAW_UP_DATE = []

        # remove punctuation
        c_str = name.translate(str.maketrans('', '', string.punctuation))

        f = c_str.split()
        self.WORD_LIST = []
        for w in f:
            if w not in _common_words:
                self.WORD_LIST.append(w)

    def Match_Draw_Up_Customer(self, name, draw_up_date, active_card_max):

        if (self.CUSTOMER == name):
            # exact match, already captured
            return

        c_str = name.translate(str.maketrans('', '', string.punctuation))

        f = c_str.split()

        check_list = []
        for w in f:
            if (w not in _common_words) and (len(w)>1) and (not w.isnumeric()):
                check_list.append(w)

        percent_diff = round((abs(self.ACTIVE_CARD_MAX - active_card_max) / ((self.ACTIVE_CARD_MAX+active_card_max)/2)),2)

        #date_format = "%Y-%m-%d"
        #d1_date = datetime.strptime(draw_up_date.astype(str), date_format)
        #d2_date = datetime.strptime(self.DRAW_DOWN_DATE.astype(str), date_format)

        delta_between_drop_and_rise = round(abs((draw_up_date-self.DRAW_DOWN_DATE).days)/30.,0)

        for w_to_check in check_list:
            for w in self.WORD_LIST:
                if w_to_check==w:

                    if not name in(self.MATCHING_CUSTOMERS) and(delta_between_drop_and_rise<=4)and(percent_diff<=0.5) :
                        self.MATCHING_CUSTOMERS.append(name)
                        self.PERCENT_DIFFERENCE.append(percent_diff)
                        self.DAYS_DIFFERENCE.append(delta_between_drop_and_rise)
                        self.DRAW_UP_DATE.append(draw_up_date)
                        break;
# Out:
# 2173 screening against common words

# %%
import time

def do_save_log(_matching_process_log_time, _matching_process_log_event):

    df_matching_log = pd.DataFrame(_matching_process_log_time)
    if len(df_matching_log)>0:

        df_matching_log.columns = ['LOG_TIME']
        df_matching_log['LOG_EVENT'] = _matching_process_log_event

        MATCHING_PROCESS_LOG_V_df = df_matching_log
        MATCHING_PROCESS_LOG_V = dataiku.Dataset("MATCHING_PROCESS_LOG_V")
        MATCHING_PROCESS_LOG_V.write_with_schema(MATCHING_PROCESS_LOG_V_df)

        print()

def do_save_direct_matches(_direct_customer, _direct_match, _direct_draw_up_date):

    df_matches = pd.DataFrame(_direct_customer)
    if len(df_matches)>0:

        print()
        print("saving", len(df_matches), "1-1 matching records")
        print()

        df_matches.columns = ['CUSTOMER']
        df_matches["MATCH_CUSTOMER"] = _direct_match
        df_matches["DRAW_UP_DATE"] = _direct_draw_up_date

        MATCHES_1_TO_1_STAGING_V_df = df_matches
        MATCHES_1_TO_1_STAGING_V = dataiku.Dataset("MATCHES_1_TO_1_STAGING_V")
        MATCHES_1_TO_1_STAGING_V.write_with_schema(MATCHES_1_TO_1_STAGING_V_df)

        print()

def do_save_multiple_matches(_multiple_customer, _multiple_matches, _multiple_drop_dates):

    df_multiple_matches = pd.DataFrame(_multiple_customer)

    if len(df_multiple_matches)>0:

        print()
        print("saving", len(df_multiple_matches), "1-n matching records")
        print()

        df_multiple_matches.columns = ['CUSTOMER']
        df_multiple_matches["MATCH_CUSTOMER"] = _multiple_matches
        df_multiple_matches["DRAW_UP_DATE"] = _multiple_drop_dates

        MATCHES_1_TO_N_STAGING_V_df = df_multiple_matches
        MATCHES_1_TO_N_STAGING_V = dataiku.Dataset("MATCHES_1_TO_N_STAGING_V")
        MATCHES_1_TO_N_STAGING_V.write_with_schema(MATCHES_1_TO_N_STAGING_V_df)

        print()

# %%
df_down = df_down_full
df_up = df_up_full

_processed_customers = []
verbose = False

_matching_process_log_time = []
_matching_process_log_event = []

_direct_customer = []
_direct_match = []
_direct_draw_up_date = []

_multiple_customer = []
_multiple_matches = []
_multiple_drop_dates = []

_no_match_customer = []

save_every_n = 50
to_save_counter = 0
print_every_n = 25

print(len(df_down), "filtered down rows")
print(len(df_up), "filtered up rows")

_customers = []

t0 = time.time()

for index, row in df_down.iterrows():

    customer = row['CUSTOMER']
    draw_down_date = row['DRAW_DOWN_DATE']
    active_card_max = row['ACTIVE_CARD_MAX']

    c = Draw_Down_Customer(customer, draw_down_date, active_card_max)

    _customers.append(c)

idx = 0

_matching_process_log_time.append(str(pd.Timestamp.now()))
_matching_process_log_event.append(" processing range " + str(len(_customers)) + " Draw Down Customers")
do_save_log(_matching_process_log_time, _matching_process_log_event)

max_idx = 5

for c in _customers:
    
    idx+=1
    
    #self.CUSTOMER = name
    #self.DRAW_DOWN_DATE = draw_down_date
    #self.ACTIVE_CARD_MAX = active_card_max
    print(c.CUSTOMER, c.DRAW_DOWN_DATE, c.ACTIVE_CARD_MAX)

    if idx>max_idx:
        break;
# Out:
# 14444 filtered down rows
# 5848 filtered up rows
# 1 rows successfully written (MurqORRJ6v)
#
#  HOLDINGS LLC DBA SECURITY INDUSTRIES
# 0067 BLACK & DECKER
# 0452009108911
# 0496003403045 EAST BAY MECHANICAL
# 0516 MONSANTO CANADA INC.
# 92098 CANADA
# 92098 CANADA 2019-05-01 00:00:00+00:00 1.0
# 9232-1645 QUEBEC INC
# 9232-1645 QUEBEC INC 2022-03-01 00:00:00+00:00 2.0
# 9257-6461 QUEBEC INC
# 9257-6461 QUEBEC INC 2019-03-01 00:00:00+00:00 1.0
# 9279 CINRAM INTERNATIONAL INC.
# 9279 CINRAM INTERNATIONAL INC. 2021-05-01 00:00:00+00:00 7.0
# 9285-2094 QC INC GESTION JIMMY
# 9285-2094 QC INC GESTION JIMMY 2022-03-01 00:00:00+00:00 1.0
# 9292-1436 QC INC STEAMATIC
# 9292-1436 QC INC STEAMATIC 2022-03-01 00:00:00+00:00 19.0
# 9298-3816 QUE INC
# 9298-3816 QUE INC 2020-03-01 00:00:00+00:00 1.0
# 933944 ON LTD O/A ST ONGE RECREATION
# 933944 ON LTD O/A ST ONGE RECREATION 2022-05-01 00:00:00+00:00 5.0
# 9349-3831 QUEBEC INC
# 9349-3831 QUEBEC INC 2019-09-01 00:00:00+00:00 2.0
# 9477 CASE DESIGN (PHH1)
# 9477 CASE DESIGN (PHH1) 2021-04-01 00:00:00+00:00 1.0
# 94TH ST BEER  WINE
# 94TH ST BEER  WINE 2021-07-01 00:00:00+00:00 4.0
# 95887-KOMATSU FORKLIFT U.S.A.,
# 95887-KOMATSU FORKLIFT U.S.A., 2019-11-01 00:00:00+00:00 7.0
# 972066 ONT INC
# 972066 ONT INC 2020-02-01 00:00:00+00:00 2.0
# 9725 BIOVERATIV CANADA INC
# 9725 BIOVERATIV CANADA INC 2019-02-01 00:00:00+00:00 2.0
# 9746 JDHM NETTOYAGE INC
# 9746 JDHM NETTOYAGE INC 2021-01-01 00:00:00+00:00 22.0
# 9825 CENOVUS ENERGY INC
# 9825 CENOVUS ENERGY INC 2019-04-01 00:00:00+00:00 23.0
# 9970 BROGAN SAFETY SUPPLY LTD
# 9970 BROGAN SAFETY SUPPLY LTD 2020-06-01 00:00:00+00:00 17.0
# @ HOME MEDICAL INC
# @ HOME MEDICAL INC 2021-08-01 00:00:00+00:00 2.0
# A  A COINS  STAMPS COLLECTABLES
# A  A COINS  STAMPS COLLECTABLES 2020-10-01 00:00:00+00:00 6.0
# A  A SEWER  DRAIN MAINTENANCE INC
# A  A SEWER  DRAIN MAINTENANCE INC 2019-10-01 00:00:00+00:00 5.0
# A  A SIGNS
# A  A SIGNS 2020-11-01 00:00:00+00:00 1.0
# A  B AUTO REPAIR  TIRES INC
# A  B AUTO REPAIR  TIRES INC 2021-12-01 00:00:00+00:00 4.0
# A  C OLIVAREZ LLC
# A  C OLIVAREZ LLC 2020-04-01 00:00:00+00:00 1.0
# A  E ELECTRIC
# A  E ELECTRIC 2019-07-01 00:00:00+00:00 4.0
# A  E FORMS INC
# A  E FORMS INC 2021-10-01 00:00:00+00:00 3.0
# A  H SYSTEMS INC
# A  H SYSTEMS INC 2021-01-01 00:00:00+00:00 4.0
# A  I INC
# A  I INC 2021-08-01 00:00:00+00:00 9.0
# A  J CONVERTING
# A  J CONVERTING 2020-07-01 00:00:00+00:00 2.0
# A  J RAPAPORT PARTNERS 61
# A  J RAPAPORT PARTNERS 61 2021-01-01 00:00:00+00:00 7.0
# A  L TRANSPORTATION
# A  L TRANSPORTATION 2021-02-01 00:00:00+00:00 5.0
# A  M SITE SERVICE OF SARASOTA LLC
# A  M SITE SERVICE OF SARASOTA LLC 2021-03-01 00:00:00+00:00 4.0
# A  W SIGN CO INC
# A  W SIGN CO INC 2020-04-01 00:00:00+00:00 1.0
# A & A SECURITY & INVESTIGATION
# A & A SECURITY & INVESTIGATION 2020-06-01 00:00:00+00:00 4.0
# A & B WELL DRILLING OF OSCEOLA
# A & B WELL DRILLING OF OSCEOLA 2021-12-01 00:00:00+00:00 4.0
# A & E VENDS INC
# A & E VENDS INC 2019-05-01 00:00:00+00:00 1.0
# A & E WHOLESALE LLC
# A & E WHOLESALE LLC 2021-10-01 00:00:00+00:00 2.0
# A & F DI CARLO CONST INC
# A & F DI CARLO CONST INC 2021-12-01 00:00:00+00:00 3.0
# A & J ELECTRICAL SERVICE
# A & J ELECTRICAL SERVICE 2022-03-01 00:00:00+00:00 5.0
# A & J ENTERPRISES, LLC
# A & J ENTERPRISES, LLC 2019-10-01 00:00:00+00:00 2.0
# A & L DOORS & HARDWARE
# A & L DOORS & HARDWARE 2022-02-01 00:00:00+00:00 4.0
# A & R NISSLEY INC
# A & R NISSLEY INC 2019-04-01 00:00:00+00:00 3.0
# A & R SOLAR
# A & R SOLAR 2019-07-01 00:00:00+00:00 27.0
# A & R WELDING CO INC
# A & R WELDING CO INC 2022-03-01 00:00:00+00:00 3.0
# A & S TRANSPORTATION
# A & S TRANSPORTATION 2019-01-01 00:00:00+00:00 70.0
# A & W ELECTRIC CO INC
# A & W ELECTRIC CO INC 2022-02-01 00:00:00+00:00 7.0
# A & W EXPRESS INC
# A & W EXPRESS INC 2020-02-01 00:00:00+00:00 3.0
# A & W Furniture, Inc.
# A & W Furniture, Inc. 2022-04-01 00:00:00+00:00 2.0
# A & W SERVICES LLC
# A & W SERVICES LLC 2020-03-01 00:00:00+00:00 3.0
# A 1 NOEL TOWING CO
# A 1 NOEL TOWING CO 2020-08-01 00:00:00+00:00 1.0
# A 1 SPOTLESS INC
# A 1 SPOTLESS INC 2019-09-01 00:00:00+00:00 3.0
# A 1 TERMITE  PEST CONTROL 2
# A 1 TERMITE  PEST CONTROL 2 2020-06-01 00:00:00+00:00 4.0
# A 1 TINT & ACCESSORIES INC
# A 1 TINT & ACCESSORIES INC 2021-10-01 00:00:00+00:00 2.0
# A 2 Z MECHANICAL CONTRACTORS
# A 2 Z MECHANICAL CONTRACTORS 2021-07-01 00:00:00+00:00 2.0
# A 5 STARR ENERGY CORPORATION
# A 5 STARR ENERGY CORPORATION 2020-10-01 00:00:00+00:00 4.0
# A A A A TEST COMPANY
# A A A A TEST COMPANY 2020-01-01 00:00:00+00:00 2.0
# A A A EXECUTIVE COMMUNICATIONS
# A A A EXECUTIVE COMMUNICATIONS 2021-12-01 00:00:00+00:00 2.0
# A A A FLAG & BANNER MFG CO INC
# A A A FLAG & BANNER MFG CO INC 2020-02-01 00:00:00+00:00 23.0
# A A A PARTY RENTAL LLC
# A A A PARTY RENTAL LLC 2019-09-01 00:00:00+00:00 3.0
# A A A PRESSURE WASHING & SWEEP
# A A A PRESSURE WASHING & SWEEP 2022-03-01 00:00:00+00:00 30.0
# A A K MECHANICAL INC
# A A K MECHANICAL INC 2021-12-01 00:00:00+00:00 29.0
# A A STUCCO & DRYWALL INC
# A A STUCCO & DRYWALL INC 2022-01-01 00:00:00+00:00 20.0
# A A SUPERIOR TRANSPORTATION TAXI
# A A SUPERIOR TRANSPORTATION TAXI 2020-02-01 00:00:00+00:00 3.0
# A ADVANCED SEPTIC
# A ADVANCED SEPTIC 2019-12-01 00:00:00+00:00 5.0
# A AIR COMPANY INCORPORATED
# A AIR COMPANY INCORPORATED 2021-02-01 00:00:00+00:00 33.0
# A ALL ANIMAL CONTROL OF TAMPA BAY LLC
# A ALL ANIMAL CONTROL OF TAMPA BAY LLC 2019-06-01 00:00:00+00:00 2.0
# A ALL PRO PLUMBING OF CENTRAL
# A ALL PRO PLUMBING OF CENTRAL 2021-08-01 00:00:00+00:00 10.0
# A AND A COOLING AND HEATING
# A AND A COOLING AND HEATING 2021-10-01 00:00:00+00:00 9.0
# A AND B SWEEPING LLC
# A AND B SWEEPING LLC 2019-04-01 00:00:00+00:00 2.0
# A B A P A
# A B A P A 2020-08-01 00:00:00+00:00 1.0
# A B C ADVENTURES INC
# A B C ADVENTURES INC 2021-10-01 00:00:00+00:00 4.0
# A B C CARE INC
# A B C CARE INC 2020-08-01 00:00:00+00:00 8.0
# A B C DEMOLITION INC
# A B C DEMOLITION INC 2019-10-01 00:00:00+00:00 26.0
# A B C GREAT BIGINNING AT JORDAN L
# A B C GREAT BIGINNING AT JORDAN L 2019-10-01 00:00:00+00:00 1.0
# A B C LIMOUSINE
# A B C LIMOUSINE 2019-11-01 00:00:00+00:00 2.0
# A B C PROFESSIONAL TREE SERVICE
# A B C PROFESSIONAL TREE SERVICE 2019-05-01 00:00:00+00:00 124.0
# A B CLOSETS INC
# A B CLOSETS INC 2020-02-01 00:00:00+00:00 5.0
# A B CONSULTANTS INC
# A B CONSULTANTS INC 2019-01-01 00:00:00+00:00 3.0
# A B M EQUIPMENT & SUPPLY LLC
# A B M EQUIPMENT & SUPPLY LLC 2021-06-01 00:00:00+00:00 14.0
# A B M LANDSCAPE
# A B M LANDSCAPE 2021-03-01 00:00:00+00:00 3.0
# A B NATURAL STONE AND LANDSCAPE PRODUCTS
# A B NATURAL STONE AND LANDSCAPE PRODUCTS 2019-10-01 00:00:00+00:00 1.0
# A BARK ABOVE THE BEST MOBILE GROOMING
# A BARK ABOVE THE BEST MOBILE GROOMING 2021-11-01 00:00:00+00:00 4.0
# A BELL SERVICE GROUP LLC
# A BELL SERVICE GROUP LLC 2022-01-01 00:00:00+00:00 10.0
# A BUSY B SERVICE CO
# A BUSY B SERVICE CO 2019-11-01 00:00:00+00:00 2.0
# A C EXPRESS LINE INC
# A C EXPRESS LINE INC 2019-10-01 00:00:00+00:00 2.0
# A C REIDER DRILLING COMPANY IN
# A C REIDER DRILLING COMPANY IN 2020-08-01 00:00:00+00:00 3.0
# A COMPRESSOR SERVICE
# A COMPRESSOR SERVICE 2019-11-01 00:00:00+00:00 4.0
# A CORE CONCRETE CUTTING INC (2
# A CORE CONCRETE CUTTING INC (2 2019-08-01 00:00:00+00:00 74.0
# A CORE OF IDAHO INC
# A CORE OF IDAHO INC 2019-08-01 00:00:00+00:00 13.0
# A D DELIVERY SERVICES CORP
# A D DELIVERY SERVICES CORP 2019-01-01 00:00:00+00:00 5.0
# A D T S INC
# A D T S INC 2021-05-01 00:00:00+00:00 2.0
# A DAY GRAPE INC
# A DAY GRAPE INC 2020-10-01 00:00:00+00:00 6.0
# A DOG GONE GOOD PLACE
# A DOG GONE GOOD PLACE 2021-03-01 00:00:00+00:00 2.0
# A E G CYCLING LLC
# A E G CYCLING LLC 2019-05-01 00:00:00+00:00 330.0
# A F L NETWORK SERVICES
# A F L NETWORK SERVICES 2021-09-01 00:00:00+00:00 198.0
# A G B INVESTIGATIVE SERVICES INC
# A G B INVESTIGATIVE SERVICES INC 2019-07-01 00:00:00+00:00 83.0
# A G REPAIR LLC
# A G REPAIR LLC 2020-06-01 00:00:00+00:00 9.0
# A GAS US INC
# A GAS US INC 2022-01-01 00:00:00+00:00 10.0
# A GENERAL PAINTING  SERVICES INC
# A GENERAL PAINTING  SERVICES INC 2019-12-01 00:00:00+00:00 4.0
# A GRIMES  DRANHOFER DBA CASTLE KEEP
# A GRIMES  DRANHOFER DBA CASTLE KEEP 2019-03-01 00:00:00+00:00 2.0
# A H HARRIS AND SONS INC
# A H HARRIS AND SONS INC 2019-01-01 00:00:00+00:00 83.0
# A HUDSON VALLEY LIMOUSINE I(04
# A HUDSON VALLEY LIMOUSINE I(04 2020-03-01 00:00:00+00:00 12.0
# A J E B INC
# A J E B INC 2022-04-01 00:00:00+00:00 4.0
# A J INSTALLATION LLC
# A J INSTALLATION LLC 2020-08-01 00:00:00+00:00 2.0
# A J M GROUP LLC
# A J M GROUP LLC 2019-05-01 00:00:00+00:00 4.0
# A J PROPERTIES INC
# A J PROPERTIES INC 2019-01-01 00:00:00+00:00 2.0
# A J SCHRAFEL PAP
# A J SCHRAFEL PAP 2019-02-01 00:00:00+00:00 2.0
# A JAMES MONTGOMERY & ASSOC
# A JAMES MONTGOMERY & ASSOC 2019-02-01 00:00:00+00:00 1.0
# A JOHNSON HEATING INC
# A JOHNSON HEATING INC 2020-03-01 00:00:00+00:00 2.0
# A K  R WHIPPLE PLUMBING  HEATING COMPANY INC
# A K  R WHIPPLE PLUMBING  HEATING COMPANY INC 2022-04-01 00:00:00+00:00 111.0
# A K GLASS MENDERS
# A K GLASS MENDERS 2021-12-01 00:00:00+00:00 5.0
# A K INDUSTRIAL CONTRACTORS INC
# A K INDUSTRIAL CONTRACTORS INC 2020-03-01 00:00:00+00:00 13.0
# A K UTILITY CONSTRUCTION LLC
# A K UTILITY CONSTRUCTION LLC 2020-12-01 00:00:00+00:00 13.0
# A L E HEAVYLIFT INC
# A L E HEAVYLIFT INC 2020-04-01 00:00:00+00:00 30.0
# A L L MASONRY CONSTRUCTION CO
# A L L MASONRY CONSTRUCTION CO 2019-03-01 00:00:00+00:00 2.0
# A L SCHUTZMAN CO INC
# A L SCHUTZMAN CO INC 2022-04-01 00:00:00+00:00 2.0
# A LIBERONI INC
# A LIBERONI INC 2020-01-01 00:00:00+00:00 11.0
# A M  M UTILITIES CONSTRUCTION
# A M  M UTILITIES CONSTRUCTION 2020-03-01 00:00:00+00:00 4.0
# A M A EXTERMINATING
# A M A EXTERMINATING 2021-08-01 00:00:00+00:00 5.0
# A M D INDUSTRIES INC
# A M D INDUSTRIES INC 2020-12-01 00:00:00+00:00 18.0
# A M D S LLC
# A M D S LLC 2021-08-01 00:00:00+00:00 6.0
# A M F M INC
# A M F M INC 2021-10-01 00:00:00+00:00 17.0
# A M I KIDS PENSACOLA INC
# A M I KIDS PENSACOLA INC 2019-12-01 00:00:00+00:00 2.0
# A M PERRICELLI ASSOCIATES
# A M PERRICELLI ASSOCIATES 2020-12-01 00:00:00+00:00 3.0
# A M SERVICES INC 3
# A M SERVICES INC 3 2019-10-01 00:00:00+00:00 2.0
# A M TECHNICAL SOLUTIONS INC
# A M TECHNICAL SOLUTIONS INC 2022-01-01 00:00:00+00:00 8.0
# A M V INC
# A M V INC 2022-04-01 00:00:00+00:00 6.0
# A M X ENTERPRISES INC
# A M X ENTERPRISES INC 2020-04-01 00:00:00+00:00 47.0
# A MEN DRYWALL INC
# A MEN DRYWALL INC 2021-04-01 00:00:00+00:00 1.0
# A MERRIE SWEEPE CHIMNEY SERVIC
# A MERRIE SWEEPE CHIMNEY SERVIC 2020-02-01 00:00:00+00:00 6.0
# A N K TRUCKING
# A N K TRUCKING 2020-04-01 00:00:00+00:00 2.0
# A N W INC
# A N W INC 2020-03-01 00:00:00+00:00 5.0
# A NATIONAL RECOVERY SERVICES
# A NATIONAL RECOVERY SERVICES 2021-09-01 00:00:00+00:00 3.0
# A NATIVE TREE SERVICE INC
# A NATIVE TREE SERVICE INC 2020-02-01 00:00:00+00:00 3.0
# A ONE TOWING
# A ONE TOWING 2019-07-01 00:00:00+00:00 1.0
# A OX WELDING SUPPLY CO
# A OX WELDING SUPPLY CO 2021-10-01 00:00:00+00:00 3.0
# A P C O PLASTICS
# A P C O PLASTICS 2020-10-01 00:00:00+00:00 2.0
# A P E X CONSULTING SERVICES
# A P E X CONSULTING SERVICES 2020-03-01 00:00:00+00:00 2.0
# A P E X INTERNATIONAL TRANSPOR
# A P E X INTERNATIONAL TRANSPOR 2020-03-01 00:00:00+00:00 26.0
# A P MARBLE AND GRANITE INC
# A P MARBLE AND GRANITE INC 2019-08-01 00:00:00+00:00 1.0
# A P PRODUCTION  SERVICE
# A P PRODUCTION  SERVICE 2020-09-01 00:00:00+00:00 3.0
# A PEACH OF A PARTY INC
# A S T CONSTRUCTION INC 2019-11-01 00:00:00+00:00 2.0
# A T H RECOVERY LLC
# A T H RECOVERY LLC 2020-03-01 00:00:00+00:00 5.0
# A T L C LAWN SERVICE LLC
# A T L C LAWN SERVICE LLC 2020-01-01 00:00:00+00:00 2.0
# A T R A JANITORIAL SUPPLY CO I
# A T R A JANITORIAL SUPPLY CO I 2021-03-01 00:00:00+00:00 3.0
# A TEAM HEATING  COOLING
# A TEAM HEATING  COOLING 2020-06-01 00:00:00+00:00 22.0
# A TECH APPLIANCE SERVICE INC
# A TECH APPLIANCE SERVICE INC 2020-09-01 00:00:00+00:00 19.0
# A TIRE  WHEEL
# A TIRE  WHEEL 2021-11-01 00:00:00+00:00 2.0
# A TO Z COATINGS & INSULATION
# A TO Z COATINGS & INSULATION 2021-04-01 00:00:00+00:00 23.0
# A TO Z CONSTRUCTION
# A TO Z CONSTRUCTION 2019-03-01 00:00:00+00:00 6.0
# A TO Z ELECTRIC LLC
# A TO Z ELECTRIC LLC 2019-08-01 00:00:00+00:00 1.0
# A TO Z SECURITY SERVICES
# A TO Z SECURITY SERVICES 2019-07-01 00:00:00+00:00 9.0
# A TOWING SERVICE LTD
# A TOWING SERVICE LTD 2021-04-01 00:00:00+00:00 5.0
# A V C OF THE TREASURE COAST INC
# A V C OF THE TREASURE COAST INC 2020-03-01 00:00:00+00:00 2.0
# A V EXPERIENCE INC 0453
# A V EXPERIENCE INC 0453 2020-01-01 00:00:00+00:00 2.0
# A V GUYS LLC
# A V GUYS LLC 2020-06-01 00:00:00+00:00 7.0
# A V L ELEVATOR CO
# A V L ELEVATOR CO 2019-09-01 00:00:00+00:00 73.0
# A V TECHNOLOGY SOLUTIONS LLC
# A V TECHNOLOGY SOLUTIONS LLC 2021-08-01 00:00:00+00:00 5.0
# A V V R INC
# A V V R INC 2021-09-01 00:00:00+00:00 14.0
# A Z CONTRACTING SERVICES LLC
# A Z CONTRACTING SERVICES LLC 2020-02-01 00:00:00+00:00 13.0
# A Z NURSERY
# A Z NURSERY 2019-04-01 00:00:00+00:00 1.0
# A Z PROPERTY RENOVATION INC
# A Z PROPERTY RENOVATION INC 2019-08-01 00:00:00+00:00 4.0
# A ZOO FOR YOU LLC
# A ZOO FOR YOU LLC 2019-12-01 00:00:00+00:00 6.0
# A-1 MECHANICAL, LLC
# A-1 MECHANICAL, LLC 2021-03-01 00:00:00+00:00 12.0
# A-BEST PAINTING CONTRACTOR
# A-BEST PAINTING CONTRACTOR 2019-11-01 00:00:00+00:00 2.0
# A.E. SECURITY CORP.
# A.E. SECURITY CORP. 2022-01-01 00:00:00+00:00 5.0
# A.S.N. INC
# A.S.N. INC 2021-04-01 00:00:00+00:00 1.0
# A/C GUYS INC
# A/C GUYS INC 2022-01-01 00:00:00+00:00 8.0
# A/Z CONSTRUCTION SERVICES INC
# A/Z CONSTRUCTION SERVICES INC 2021-11-01 00:00:00+00:00 6.0
# A1 CONTRACTING LLC
# A1 CONTRACTING LLC 2021-02-01 00:00:00+00:00 42.0
# A1 KWIK DRY CARPET CLEANING
# A1 KWIK DRY CARPET CLEANING 2021-01-01 00:00:00+00:00 1.0
# A1 LIMOUSINE INC
# A1 LIMOUSINE INC 2020-03-01 00:00:00+00:00 92.0
# A1 MAINTENANCE MASTER INC
# A1 MAINTENANCE MASTER INC 2021-01-01 00:00:00+00:00 2.0
# A1 SECURITY INC
# A1 SECURITY INC 2021-01-01 00:00:00+00:00 3.0
# A1 SPA REPAIR
# A1 SPA REPAIR 2021-02-01 00:00:00+00:00 2.0
# A1 UTAH HOME INSPECTOR
# A1 UTAH HOME INSPECTOR 2019-09-01 00:00:00+00:00 4.0
# A1A TRANSPORTATION SERVICES CO
# A1A TRANSPORTATION SERVICES CO 2019-07-01 00:00:00+00:00 4.0
# A3 CREATIVE SOLUTIONS
# A3 CREATIVE SOLUTIONS 2022-02-01 00:00:00+00:00 3.0
# AA ACCURATE TRUCK & TIRE REPAI
# AA ACCURATE TRUCK & TIRE REPAI 2021-05-01 00:00:00+00:00 13.0
# AA APPRAISALS
# AA APPRAISALS 2020-01-01 00:00:00+00:00 1.0
# AA FENCE CONSTRUCTION
# AA FENCE CONSTRUCTION 2019-02-01 00:00:00+00:00 3.0
# AA HYDRAULIC SERVICE
# AA HYDRAULIC SERVICE 2021-03-01 00:00:00+00:00 1.0
# AAA NCNU (5ES0)
# AAA NCNU (5ES0) 2021-03-01 00:00:00+00:00 593.0
# AABILITY TERMITE  PEST CONTROL LLC
# AABILITY TERMITE  PEST CONTROL LLC 2020-01-01 00:00:00+00:00 2.0
# AAC HOLDINGS INC
# AAC HOLDINGS INC 2020-06-01 00:00:00+00:00 95.0
# AAFFINITY CONTRACTING
# AAFFINITY CONTRACTING 2019-11-01 00:00:00+00:00 2.0
# AAGTEN INVSTMNTS LTDDBA ATLAS CAISSONS
# AAGTEN INVSTMNTS LTDDBA ATLAS CAISSONS 2019-08-01 00:00:00+00:00 9.0
# AALA HOLDING COMPANY INC
# AALA HOLDING COMPANY INC 2021-02-01 00:00:00+00:00 14.0
# AALL AMERICAN CREDIT CARD SOLUTIONS INC
# AALL AMERICAN CREDIT CARD SOLUTIONS INC 2020-01-01 00:00:00+00:00 16.0
# AANCO FENCE INC
# AANCO FENCE INC 2019-10-01 00:00:00+00:00 5.0
# AARON OSHRY PROF CORP O/A
# AARON OSHRY PROF CORP O/A 2020-11-01 00:00:00+00:00 5.0
# AAVIS PLUMBING HEATING  AIR INC
# AAVIS PLUMBING HEATING  AIR INC 2020-05-01 00:00:00+00:00 32.0
# AB FASTENERS INC
# AB FASTENERS INC 2022-04-01 00:00:00+00:00 3.0
# AB HARKER  ASSOCIATES LLC
# AB HARKER  ASSOCIATES LLC 2019-09-01 00:00:00+00:00 3.0
# AB POOL SERVICES LLC
# AB POOL SERVICES LLC 2021-12-01 00:00:00+00:00 2.0
# ABALINE PAPER PRODUCTS
# ABALINE PAPER PRODUCTS 2019-02-01 00:00:00+00:00 2.0
# ABATEMENT PROFESSIONALS CORP
# ABATEMENT PROFESSIONALS CORP 2020-09-01 00:00:00+00:00 10.0
# ABB INC 0325
# ABB INC 0325 2020-03-01 00:00:00+00:00 31.0
# ABB INC 0AJ2
# ABB INC 0AJ2 2020-10-01 00:00:00+00:00 30.0
# ABBA SHRINE
# ABBA SHRINE 2020-12-01 00:00:00+00:00 8.0
# ABBEY COORDINATED INTERIORS INC
# ABBEY COORDINATED INTERIORS INC 2021-12-01 00:00:00+00:00 3.0
# ABBEY ST PAUL
# ABBEY ST PAUL 2019-07-01 00:00:00+00:00 5.0
# ABBOTT MECHANICAL CONTRACTORS INC
# ABBOTT MECHANICAL CONTRACTORS INC 2020-02-01 00:00:00+00:00 2.0
# ABBY CONTRACTING
# ABBY CONTRACTING 2022-05-01 00:00:00+00:00 2.0
# ABC CUSTOMS BROKERS LTD
# ABC CUSTOMS BROKERS LTD 2020-02-01 00:00:00+00:00 1.0
# ABC DENTAL LAB INC
# ABC DENTAL LAB INC 2019-08-01 00:00:00+00:00 3.0
# ABC DISCOUNT APPLIANCES INC
# ABC DISCOUNT APPLIANCES INC 2019-02-01 00:00:00+00:00 2.0
# ABC SUPPLY CO
# ABC SUPPLY CO 2019-05-01 00:00:00+00:00 1.0
# ABC USED PARTS INC
# ABC USED PARTS INC 2020-01-01 00:00:00+00:00 1.0
# ABCOR GARAGE DOOR SERVICE INC
# ABCOR GARAGE DOOR SERVICE INC 2019-06-01 00:00:00+00:00 1.0
# ABEL TRANSMISSION INC
# ABEL TRANSMISSION INC 2021-12-01 00:00:00+00:00 4.0
# ABELL ELEVATOR SERVICE COMP 2
# ABELL ELEVATOR SERVICE COMP 2 2019-08-01 00:00:00+00:00 68.0
# ABELL MECHANICAL INC
# ABELL MECHANICAL INC 2022-03-01 00:00:00+00:00 3.0
# ABERRATION INC
# ABERRATION INC 2019-07-01 00:00:00+00:00 3.0
# ABG SERVICE SOLUTIONS LLC
# ABG SERVICE SOLUTIONS LLC 2019-03-01 00:00:00+00:00 14.0
# ABI DOCUMENT SUPPORT SERVICES LLC
# ABI DOCUMENT SUPPORT SERVICES LLC 2020-09-01 00:00:00+00:00 3.0
# ABILENE AUCTION INC
# ABILENE AUCTION INC 2019-09-01 00:00:00+00:00 3.0
# ABILENE PLUMBING  HEATING INC
# ABILENE PLUMBING  HEATING INC 2019-09-01 00:00:00+00:00 4.0
# ABILITIES OF NORTHWEST JERSEY
# ABILITIES OF NORTHWEST JERSEY 2019-02-01 00:00:00+00:00 29.0
# ABILITY FLOORING
# ABILITY FLOORING 2019-03-01 00:00:00+00:00 1.0
# ABJ AIR CONDITIONING AND APPLIANCE INC
# ABJ AIR CONDITIONING AND APPLIANCE INC 2019-02-01 00:00:00+00:00 2.0
# ABK ENTERPRISES INC
# ABK ENTERPRISES INC 2022-03-01 00:00:00+00:00 2.0
# ABLE ALLOY INC
# ABLE ALLOY INC 2021-01-01 00:00:00+00:00 3.0
# ABLE AND READY TRUCKING
# ABLE AND READY TRUCKING 2019-01-01 00:00:00+00:00 3.0
# ABLE APPLIANCE
# ABLE APPLIANCE 2022-04-01 00:00:00+00:00 4.0
# ADAMS BUILDING MAINTENANCE 2020-09-01 00:00:00+00:00 3.0
# ADAMS MECHANICAL SERVICES LLC
# ADAMS MECHANICAL SERVICES LLC 2019-10-01 00:00:00+00:00 2.0
# ADAMS PLUMBING INC
# ADAMS PLUMBING INC 2020-03-01 00:00:00+00:00 6.0
# ADAMS TELEPHONE CO OP 3
# ADAMS TELEPHONE CO OP 3 2019-02-01 00:00:00+00:00 53.0
# ADAPTIVE NURSING & HEALTHC
# ADAPTIVE NURSING & HEALTHC 2019-05-01 00:00:00+00:00 43.0
# ADB SALES ASSOCIATES
# ADB SALES ASSOCIATES 2021-01-01 00:00:00+00:00 1.0
# ADCO HEAT  AIR INC
# ADCO HEAT  AIR INC 2020-01-01 00:00:00+00:00 4.0
# ADD REAL CORP
# ADD REAL CORP 2021-09-01 00:00:00+00:00 2.0
# ADDISON COUNTY SHERIFFS DEPARTMENT
# ADDISON COUNTY SHERIFFS DEPARTMENT 2021-01-01 00:00:00+00:00 13.0
# ADDSON CATERING CO INC
# ADDSON CATERING CO INC 2020-07-01 00:00:00+00:00 3.0
# ADEL TV AND APPLIANCE CO
# ADEL TV AND APPLIANCE CO 2020-03-01 00:00:00+00:00 4.0
# ADELDA HEALTH
# ADELDA HEALTH 2020-08-01 00:00:00+00:00 11.0
# ADELINE TRUCKING LLC
# ADELINE TRUCKING LLC 2020-03-01 00:00:00+00:00 6.0
# ADELWERTH BUS CORP
# ADELWERTH BUS CORP 2019-01-01 00:00:00+00:00 44.0
# ADEXMAT INC.
# ADEXMAT INC. 2021-12-01 00:00:00+00:00 2.0
# ADI AUTOMOTIVE
# ADI AUTOMOTIVE 2019-09-01 00:00:00+00:00 4.0
# ADI CONTRACTING LLC
# ADI CONTRACTING LLC 2020-11-01 00:00:00+00:00 8.0
# ADMIRAL AIR CONDITIONING  HEA
# ADMIRAL AIR CONDITIONING  HEA 2019-07-01 00:00:00+00:00 2.0
# ADMIRAL CARPET CLEANING
# ADMIRAL CARPET CLEANING 2021-08-01 00:00:00+00:00 1.0
# ADORE PRIMARY HOME CARE INC
# ADORE PRIMARY HOME CARE INC 2022-03-01 00:00:00+00:00 4.0
# ADORNED BYHER ENTERPRISES LLC
# ADORNED BYHER ENTERPRISES LLC 2019-01-01 00:00:00+00:00 1.0
# ADR APPLIANCE SERVICE LLC
# ADR APPLIANCE SERVICE LLC 2022-04-01 00:00:00+00:00 4.0
# ADRIEN QUIRION INC
# ...
# WINDSOR INDUSTRIES INC
# WINDSOR INDUSTRIES INC 2022-03-01 00:00:00+00:00 1.0
# WINDSTORM ENTERPRISES INC
# WINDSTORM ENTERPRISES INC 2022-01-01 00:00:00+00:00 1.0
# WINDSTORM MITIGATION INC
# WINDSTORM MITIGATION INC 2020-03-01 00:00:00+00:00 2.0
# WINGATE MANAGEMENT LLC
# WINGATE MANAGEMENT LLC 2019-11-01 00:00:00+00:00 3.0
# WINMILL MARO D OR TAMARA
# WINMILL MARO D OR TAMARA 2021-08-01 00:00:00+00:00 3.0
# WINONA COUNTY
# WRIGHTS LANDSCAPING  IRRIGATION
# WRIGHTS LANDSCAPING  IRRIGATION 2020-10-01 00:00:00+00:00 2.0
# WRIGHTWAY HEATING & COOLING
# WRIGHTWAY HEATING & COOLING 2022-01-01 00:00:00+00:00 5.0
# WSP CANADA INC
# WSP CANADA INC 2019-09-01 00:00:00+00:00 8.0
# WSS INDUSTRIAL STEEL INC
# WSS INDUSTRIAL STEEL INC 2022-05-01 00:00:00+00:00 4.0
# WTS DISTRIBUTORS
# WTS DISTRIBUTORS 2021-02-01 00:00:00+00:00 10.0
# WUESTHOFF HEALTH SYSTEMS
# WUESTHOFF HEALTH SYSTEMS 2019-04-01 00:00:00+00:00 7.0
# WULF BROS INC
# WULF BROS INC 2019-07-01 00:00:00+00:00 38.0
# WULF BROTHERS
# WULF BROTHERS 2019-08-01 00:00:00+00:00 2.0
# WURTH SERVICE SUPPLY INC 2
# WURTH SERVICE SUPPLY INC 2 2022-01-01 00:00:00+00:00 59.0
# WWGAF INC
# WWGAF INC 2021-02-01 00:00:00+00:00 41.0
# WYANDOTTE ELECTRIC
# WYANDOTTE ELECTRIC 2020-09-01 00:00:00+00:00 3.0
# WYCO INCORPORATED
# WYCO INCORPORATED 2019-01-01 00:00:00+00:00 2.0
# WYENAUGHT PROPERTY SERVICES LL
# WYENAUGHT PROPERTY SERVICES LL 2020-08-01 00:00:00+00:00 11.0
# WYER ELECTRIC LLC
# WYER ELECTRIC LLC 2021-10-01 00:00:00+00:00 4.0
# WYLER FASTLANE LLC
# WYLER FASTLANE LLC 2019-01-01 00:00:00+00:00 2.0
# WYN HOTELS LP
# WYN HOTELS LP 2020-07-01 00:00:00+00:00 1.0
# WYNN FIRE & RESCUE EQUIPMENT
# WYNN FIRE & RESCUE EQUIPMENT 2020-03-01 00:00:00+00:00 2.0
# X E I COMPANIES LLC
# X E I COMPANIES LLC 2019-01-01 00:00:00+00:00 2.0
# X L N T TINT WINDOW TINTING
# X L N T TINT WINDOW TINTING 2022-01-01 00:00:00+00:00 13.0
# X L SUPPLY INC
# X L SUPPLY INC 2021-06-01 00:00:00+00:00 5.0
# X10 ELECTRIC LLC
# X10 ELECTRIC LLC 2019-12-01 00:00:00+00:00 3.0
# XERIZONA DESIGN  LANDSCAPE LLC
# XERIZONA DESIGN  LANDSCAPE LLC 2022-04-01 00:00:00+00:00 2.0
# XL EXCAVATING INC
# XL EXCAVATING INC 2021-08-01 00:00:00+00:00 4.0
# XPRESS CAR INC
# XPRESS CAR INC 2020-08-01 00:00:00+00:00 7.0
# XPRESS SWEEPING INC
# XPRESS SWEEPING INC 2019-05-01 00:00:00+00:00 33.0
# XTREME MOTORSPORTS LLC
# XTREME MOTORSPORTS LLC 2019-07-01 00:00:00+00:00 1.0
# XTREME SERVICES INC2
# XTREME SERVICES INC2 2021-01-01 00:00:00+00:00 4.0
# Y A P A APARTMENT LIVING
# Y A P A APARTMENT LIVING 2019-04-01 00:00:00+00:00 1.0
# Y C INC
# Z 1 INVESTMENTS LLC 2021-06-01 00:00:00+00:00 10.0
# Z AND Z PARTNERS
# Z AND Z PARTNERS 2019-01-01 00:00:00+00:00 1.0
# Z EXPRESS INC
# Z EXPRESS INC 2019-03-01 00:00:00+00:00 9.0
# Z MANAGEMENT INC
# Z MANAGEMENT INC 2020-03-01 00:00:00+00:00 3.0
# Z W I L INC
# Z W I L INC 2021-04-01 00:00:00+00:00 45.0
# ZA GA ZIG SHRINE
# ZA GA ZIG SHRINE 2019-10-01 00:00:00+00:00 1.0
# ZACK RAES LLC
# ZACK RAES LLC 2019-01-01 00:00:00+00:00 3.0
# ZAFAR PRODUCE INC
# ZAFAR PRODUCE INC 2021-03-01 00:00:00+00:00 15.0
# ZAFU ZAFU
# ZAFU ZAFU 2022-05-01 00:00:00+00:00 2.0
# ZAG WHITVILLE SALES LTD. O/A STOUF
# ZAG WHITVILLE SALES LTD. O/A STOUF 2019-05-01 00:00:00+00:00 2.0
# ZALLO TRUCKING INC
# ZALLO TRUCKING INC 2019-09-01 00:00:00+00:00 10.0
# ZANADU INC
# ZANADU INC 2021-05-01 00:00:00+00:00 4.0
# ZAP LOGISTICS INC
# ZAP LOGISTICS INC 2021-02-01 00:00:00+00:00 13.0
# ZAXAN LLC
# ZAXAN LLC 2019-05-01 00:00:00+00:00 2.0
# ZAYTREY  LLC
# ZAYTREY  LLC 2019-11-01 00:00:00+00:00 2.0
# ZEBAR ENTERPRISES INC
# ZEBAR ENTERPRISES INC 2021-03-01 00:00:00+00:00 55.0
# ZEIGLER CONTRACTING INC
# ZEIGLER CONTRACTING INC 2021-02-01 00:00:00+00:00 1.0
# ZELVY ROBERT  ASSOC
# ZELVY ROBERT  ASSOC 2020-12-01 00:00:00+00:00 2.0
# ZEN CLEANING SERVICES LLC
# ZEN CLEANING SERVICES LLC 2019-06-01 00:00:00+00:00 6.0
# ZENIERS AUTOMOTIVE INC
# ZENIERS AUTOMOTIVE INC 2019-10-01 00:00:00+00:00 11.0
# ZENITH FARMS LTD
# ZENITH FARMS LTD 2021-04-01 00:00:00+00:00 3.0
# ZEPLIN SECURITY GROUP INC
# ZEPLIN SECURITY GROUP INC 2021-12-01 00:00:00+00:00 2.0
# ZEROREZ OF ATLANTA ONE 2
# ZEROREZ OF ATLANTA ONE 2 2021-09-01 00:00:00+00:00 5.0
# ZETTEL FISCHER CONTRACTING LTD
# ZETTEL FISCHER CONTRACTING LTD 2022-03-01 00:00:00+00:00 3.0
# ZEUS TREE EXPERTS INC
# ZEUS TREE EXPERTS INC 2022-04-01 00:00:00+00:00 2.0
# ZGLO TRUCKING
# ZGLO TRUCKING 2020-07-01 00:00:00+00:00 1.0
# ZHONGQUN TANG
# ZHONGQUN TANG 2022-03-01 00:00:00+00:00 2.0
# ZIEGLER ELECTRIC SERV INC
# ZIEGLER ELECTRIC SERV INC 2021-11-01 00:00:00+00:00 19.0
# ZIMAL PAINTING
# ZIMAL PAINTING 2019-07-01 00:00:00+00:00 1.0
# ZIMMER DOWNSTATE NY INC
# ZIMMER DOWNSTATE NY INC 2020-02-01 00:00:00+00:00 15.0
# ZIMMERMAN BROS FUNERAL HOME INC
# ZIMMERMAN BROS FUNERAL HOME INC 2022-01-01 00:00:00+00:00 4.0
# ZIMMERMANS TACK  PURINA FEED
# ZIMMERMANS TACK  PURINA FEED 2019-01-01 00:00:00+00:00 1.0
# ZION HILL MISSIONARY BAPTIST CHURCH
# ZION HILL MISSIONARY BAPTIST CHURCH 2019-12-01 00:00:00+00:00 1.0
# ZION LITTLE BAPTIST CHURCH
# ZION LITTLE BAPTIST CHURCH 2021-08-01 00:00:00+00:00 5.0
# ZION PROGRESSIVE CATHEDRAL INTERNATIONAL INCORPORATED
# ZION PROGRESSIVE CATHEDRAL INTERNATIONAL INCORPORATED 2021-06-01 00:00:00+00:00 1.0
# ZIRCON CORP
# ZIRCON CORP 2021-11-01 00:00:00+00:00 3.0
# ZIZZOS TRUCKING CO INC 61
# ZIZZOS TRUCKING CO INC 61 2021-11-01 00:00:00+00:00 10.0
# ZOCH CONSTRUCTION INC
# ZOCH CONSTRUCTION INC 2020-04-01 00:00:00+00:00 9.0
# ZOLADZ EXECUTIVE TRANSPORTATION
# ZOLADZ EXECUTIVE TRANSPORTATION 2020-03-01 00:00:00+00:00 17.0
# ZONE ENERGY SERVICES LLC
# ZONE ENERGY SERVICES LLC 2021-12-01 00:00:00+00:00 41.0
# ZOOM CONTRACTING INC
# ZOOM CONTRACTING INC 2021-04-01 00:00:00+00:00 5.0
# ZUBEK EMO AND PATTEN LTD
# ZUBEK EMO AND PATTEN LTD 2021-11-01 00:00:00+00:00 2.0
# ZUNIGA ROOFING INC
# ZUNIGA ROOFING INC 2022-01-01 00:00:00+00:00 5.0
# ZWICKY PROCESSING  RECYCLING INC
# ZWICKY PROCESSING  RECYCLING INC 2021-09-01 00:00:00+00:00 4.0

# %%
_matching_process_log_time.append(str(pd.Timestamp.now()))
_matching_process_log_event.append(" processing range " + str(len(_customers)) + " Draw Down Customers")
do_save_log(_matching_process_log_time, _matching_process_log_event)

if verbose:
    print(" processing range from " + str(len(_customers)) + " Draw Down Customers")

for c in _customers:

    idx+=1
    
    for index_up, row_up in df_up.iterrows():

        customer = row_up['CUSTOMER']
        draw_up_date = row_up['DRAW_UP_DATE']
        mean_du = row_up['MEAN_DU']
        std_du = row_up['STD_DU']
        active_card_max = row_up['ACTIVE_CARD_MAX']

        c.Match_Draw_Up_Customer(customer, draw_up_date, mean_du, std_du, active_card_max)

    if len(c.MATCHING_CUSTOMERS)==1:

        if not c.CUSTOMER in (_processed_customers):

            to_save_counter += 1

            _direct_customer.append(c.CUSTOMER)
            _processed_customers.append(c.CUSTOMER)
            _direct_match.append(c.MATCHING_CUSTOMERS[0])
            _processed_customers.append(c.MATCHING_CUSTOMERS[0])
            _direct_draw_up_date.append(c.DRAW_UP_DATE[0])

            if verbose:
                print()
                print("DIRECT")
                print(c.CUSTOMER, c.WORD_LIST)
                print(c.MATCHING_CUSTOMERS)
                print(c.PERCENT_DIFFERENCE)
                print(c.DAYS_DIFFERENCE)
                print("=====")
                print()

    elif len(c.MATCHING_CUSTOMERS)>1:

        if not c.CUSTOMER in (_processed_customers):

            to_save_counter += 1

            _multiple_customer.append(c.CUSTOMER)
            _processed_customers.append(c.CUSTOMER)
            _multiple_matches.append(c.MATCHING_CUSTOMERS)
            _multiple_drop_dates.append(c.DRAW_UP_DATE)

        if verbose:
            print()
            print("MULTIPLE")
            print(c.CUSTOMER, c.WORD_LIST)
            print(c.MATCHING_CUSTOMERS)
            print(c.PERCENT_DIFFERENCE)
            print(c.DAYS_DIFFERENCE)
            print("=====")
            print()

    else:

        # could not find a match, remove it from future processing
        _no_match_customer.append(c.CUSTOMER)
        _processed_customers.append(c.CUSTOMER)

    if to_save_counter>=save_every_n:

        _matching_process_log_time.append(str(pd.Timestamp.now()))
        _matching_process_log_event.append("writing datasets to snowflake")
        do_save_log(_matching_process_log_time, _matching_process_log_event)

        do_save_direct_matches(_direct_customer, _direct_match, _direct_draw_up_date)
        do_save_multiple_matches(_multiple_customer, _multiple_matches, _multiple_drop_dates)

        _matching_process_log_time.append(str(pd.Timestamp.now()))
        _matching_process_log_event.append("saved " + str(to_save_counter) + " records to snowflake.")
        do_save_log(_matching_process_log_time, _matching_process_log_event)

        to_save_counter = 0
        
    t1 = time.time()
    
    avg_duration = (((t1-t0)/idx)/60.0)
    
    if idx % print_every_n == 0:
        idx_remaining = len(_customers)-idx
        print("processing", idx, "current record:", c.CUSTOMER, ",", idx_remaining, "remaining")
        print(round(avg_duration,2), "avg mins per iteration",  round((avg_duration*idx_remaining)/60,2), "estimated hrs remaining")
        print(len(_direct_customer), "direct match records", len(_multiple_customer), "multiple match records", len(_no_match_customer), "no match records")
        print()
        
_matching_process_log_time.append(str(pd.Timestamp.now()))
_matching_process_log_event.append("writing datasets to snowflake")
do_save_log(_matching_process_log_time, _matching_process_log_event)

do_save_direct_matches(_direct_customer, _direct_match, _direct_draw_up_date)
do_save_multiple_matches(_multiple_customer, _multiple_matches, _multiple_drop_dates)

_matching_process_log_time.append(str(pd.Timestamp.now()))
_matching_process_log_event.append("saved " + str(to_save_counter) + " records to snowflake.")
do_save_log(_matching_process_log_time, _matching_process_log_event)

# %%
# Compute recipe outputs
# TODO: Write here your actual code that computes the outputs
# NB: DSS supports several kinds of APIs for reading and writing data. Please see doc.

#MATCHES_1_TO_N_STAGING_V_df = ... # Compute a Pandas dataframe to write into MATCHES_1_TO_N_STAGING_V
#MATCHES_1_TO_1_STAGING_V_df = ... # Compute a Pandas dataframe to write into MATCHES_1_TO_1_STAGING_V


# Write recipe outputs
#MATCHES_1_TO_N_STAGING_V = dataiku.Dataset("MATCHES_1_TO_N_STAGING_V")
#MATCHES_1_TO_N_STAGING_V.write_with_schema(MATCHES_1_TO_N_STAGING_V_df)
#MATCHES_1_TO_1_STAGING_V = dataiku.Dataset("MATCHES_1_TO_1_STAGING_V")
#MATCHES_1_TO_1_STAGING_V.write_with_schema(MATCHES_1_TO_1_STAGING_V_df)
